# %%
import os.path
from pathlib import Path
import numpy as np
import pandas as pd
from PIL import Image
import PIL

import sys

# %%
path ="C:/Users/abhis/Desktop/M.Tech/Study Materials/Semester 1 Assignment/Arun Sir/Project/tea sickness dataset"
data_sample_path = Path(path)
data_JPG = list(data_sample_path.glob(r"*/*.jpg"))
data_label = list(map(lambda x: os.path.split(os.path.split(x)[0])[1],data_JPG))
data_JPG_Series = pd.Series(data_JPG,name="JPG").astype(str)
data_Labels_Series = pd.Series(data_label,name="CATEGORY")
Data = pd.concat([data_JPG_Series,data_Labels_Series],axis=1)
Data1 = pd.concat([data_JPG_Series,data_Labels_Series],axis=1)
Data1
# Out:
#                                                    JPG    CATEGORY
# 0    C:\Users\abhis\Desktop\M.Tech\Study Materials\...  algal leaf
# 1    C:\Users\abhis\Desktop\M.Tech\Study Materials\...  algal leaf
# 2    C:\Users\abhis\Desktop\M.Tech\Study Materials\...  algal leaf
# 3    C:\Users\abhis\Desktop\M.Tech\Study Materials\...  algal leaf
# 4    C:\Users\abhis\Desktop\M.Tech\Study Materials\...  algal leaf
# ..                                                 ...         ...
# 880  C:\Users\abhis\Desktop\M.Tech\Study Materials\...  white spot
# 881  C:\Users\abhis\Desktop\M.Tech\Study Materials\...  white spot
# 882  C:\Users\abhis\Desktop\M.Tech\Study Materials\...  white spot
# 883  C:\Users\abhis\Desktop\M.Tech\Study Materials\...  white spot
# 884  C:\Users\abhis\Desktop\M.Tech\Study Materials\...  white spot
#
# [885 rows x 2 columns]

# %%
for i in range(len(Data)):
    image = Image.open(Data["JPG"][i])
    image = image.resize((3000,3000), PIL.Image.ANTIALIAS)                                # reading the imags and converting them into 28*28 size and grey scaling them
    image=image.convert("L")
    Data["JPG"][i]=image
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_2672\1349827561.py:3: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   image = image.resize((3000,3000), PIL.Image.ANTIALIAS)                                # reading the imags and converting them into 28*28 size and grey scaling them
#
# KeyboardInterrupt

# %%
Data
# Out:
#                                                    JPG    CATEGORY
# 0    <PIL.Image.Image image mode=L size=3000x3000 a...  algal leaf
# 1    <PIL.Image.Image image mode=L size=3000x3000 a...  algal leaf
# 2    <PIL.Image.Image image mode=L size=3000x3000 a...  algal leaf
# 3    <PIL.Image.Image image mode=L size=3000x3000 a...  algal leaf
# 4    <PIL.Image.Image image mode=L size=3000x3000 a...  algal leaf
# ..                                                 ...         ...
# 880  <PIL.Image.Image image mode=L size=3000x3000 a...  white spot
# 881  <PIL.Image.Image image mode=L size=3000x3000 a...  white spot
# 882  <PIL.Image.Image image mode=L size=3000x3000 a...  white spot
# 883  <PIL.Image.Image image mode=L size=3000x3000 a...  white spot
# 884  <PIL.Image.Image image mode=L size=3000x3000 a...  white spot
#
# [885 rows x 2 columns]

# %%
img_path=Data["JPG"][59]
img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
cv2.imshow('fig',img)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 img_path=Data["JPG"][59]
# ----> 2 img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
#       3 cv2.imshow('fig',img)
#       4 cv2.waitKey(0)
#
# NameError: name 'cv2' is not defined
